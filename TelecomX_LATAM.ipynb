# %% [markdown]
# # Importar Librerias

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import datetime as dt
import re

# %% [markdown]
# #📌 Extracción

# %%
TelecomX_Data = pd.read_json('TelecomX_Data.json')

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ## Validando datos duplicados

# %%
duplicados = TelecomX_Data['customerID'].duplicated()
if duplicados.any():
   print(duplicados)
else:
   print('No hay duplicados')
# Out:
# No hay duplicados

# %% [markdown]
# ## Ajustando el Dataframe, validando tipo de datos y ordenando.

# %%
Data_customer = pd.json_normalize(TelecomX_Data['customer'])
Data_phone = pd.json_normalize(TelecomX_Data['phone'])
Data_internet = pd.json_normalize(TelecomX_Data['internet'])
Data_account = pd.json_normalize(TelecomX_Data['account'])
TelecomX_Data_concat = pd.concat([TelecomX_Data['customerID'],TelecomX_Data['Churn'],
                                  Data_customer, Data_phone, Data_internet, Data_account],
                                 axis=1)
TelecomX_Data_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %% [markdown]
# ## Convertir y normalizar datos (Yes, No) para posterior manejo

# %%
TelecomX_Data_concat['Churn'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['Churn'].replace('No', False, inplace=True)
TelecomX_Data_concat['Churn'].replace('', False, inplace=True)
TelecomX_Data_concat['Partner'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['Partner'].replace('No', False, inplace=True)
TelecomX_Data_concat['Dependents'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['Dependents'].replace('No', False, inplace=True)
TelecomX_Data_concat['PhoneService'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['PhoneService'].replace('No', False, inplace=True)
TelecomX_Data_concat['MultipleLines'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['MultipleLines'].replace('No', False, inplace=True)
TelecomX_Data_concat['MultipleLines'].replace('No phone service', False, inplace=True)
TelecomX_Data_concat['OnlineBackup'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['OnlineBackup'].replace('No', False, inplace=True)
TelecomX_Data_concat['OnlineBackup'].replace('No internet service', False, inplace=True)
TelecomX_Data_concat['OnlineSecurity'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['OnlineSecurity'].replace('No', False, inplace=True)
TelecomX_Data_concat['OnlineSecurity'].replace('No internet service', False, inplace=True)
TelecomX_Data_concat['DeviceProtection'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['DeviceProtection'].replace('No', False, inplace=True)
TelecomX_Data_concat['DeviceProtection'].replace('No internet service', False, inplace=True)
TelecomX_Data_concat['TechSupport'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['TechSupport'].replace('No', False, inplace=True)
TelecomX_Data_concat['TechSupport'].replace('No internet service', False, inplace=True)
TelecomX_Data_concat['StreamingTV'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['StreamingTV'].replace('No', False, inplace=True)
TelecomX_Data_concat['StreamingTV'].replace('No internet service', False, inplace=True)
TelecomX_Data_concat['StreamingMovies'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['StreamingMovies'].replace('No', False, inplace=True)
TelecomX_Data_concat['StreamingMovies'].replace('No internet service', False, inplace=True)
TelecomX_Data_concat['PaperlessBilling'].replace('Yes', True, inplace=True)
TelecomX_Data_concat['PaperlessBilling'].replace('No', False, inplace=True)
TelecomX_Data_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   bool
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   bool
#  5   Dependents        7267 non-null   bool
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   bool
#  8   MultipleLines     7267 non-null   bool
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   bool
#  11  OnlineBackup      7267 non-null   bool
#  12  DeviceProtection  7267 non-null   bool
#  13  TechSupport       7267 non-null   bool
#  14  StreamingTV       7267 non-null   bool
#  15  StreamingMovies   7267 non-null   bool
#  16  Contract          7267 non-null   object
# ...

# %% [markdown]
# ## Trasnformando datos en el tipo correcto según aplique.

# %%
TelecomX_Data_concat['customerID'] = TelecomX_Data_concat['customerID'].astype(str)
TelecomX_Data_concat['SeniorCitizen'] = TelecomX_Data_concat['SeniorCitizen'].astype(bool)
TelecomX_Data_concat['Churn'] = TelecomX_Data_concat['Churn'].astype(bool)
TelecomX_Data_concat['Partner'] = TelecomX_Data_concat['Partner'].astype(bool)
TelecomX_Data_concat['Dependents'] = TelecomX_Data_concat['Dependents'].astype(bool)
TelecomX_Data_concat['PhoneService'] = TelecomX_Data_concat['PhoneService'].astype(bool)
TelecomX_Data_concat['MultipleLines'] = TelecomX_Data_concat['MultipleLines'].astype(bool)
TelecomX_Data_concat['OnlineBackup'] = TelecomX_Data_concat['OnlineBackup'].astype(bool)
TelecomX_Data_concat['OnlineSecurity'] = TelecomX_Data_concat['OnlineSecurity'].astype(bool)
TelecomX_Data_concat['DeviceProtection'] = TelecomX_Data_concat['DeviceProtection'].astype(bool)
TelecomX_Data_concat['TechSupport'] = TelecomX_Data_concat['TechSupport'].astype(bool)
TelecomX_Data_concat['StreamingTV'] = TelecomX_Data_concat['StreamingTV'].astype(bool)
TelecomX_Data_concat['StreamingMovies'] = TelecomX_Data_concat['StreamingMovies'].astype(bool)
TelecomX_Data_concat['PaperlessBilling'] = TelecomX_Data_concat['PaperlessBilling'].astype(bool)
TelecomX_Data_concat['gender'] = TelecomX_Data_concat['gender'].astype(str)
TelecomX_Data_concat['Contract'] = TelecomX_Data_concat['Contract'].astype(str)
TelecomX_Data_concat['PaymentMethod'] = TelecomX_Data_concat['PaymentMethod'].astype(str)
TelecomX_Data_concat['Charges.Total'] = TelecomX_Data_concat['Charges.Total'].replace(r'^\s*$', np.nan, regex=True)
TelecomX_Data_concat['Charges.Total'] = TelecomX_Data_concat['Charges.Total'].astype(float)
TelecomX_Data_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   bool
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   bool
#  4   Partner           7267 non-null   bool
#  5   Dependents        7267 non-null   bool
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   bool
#  8   MultipleLines     7267 non-null   bool
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   bool
#  11  OnlineBackup      7267 non-null   bool
#  12  DeviceProtection  7267 non-null   bool
#  13  TechSupport       7267 non-null   bool
#  14  StreamingTV       7267 non-null   bool
#  15  StreamingMovies   7267 non-null   bool
#  16  Contract          7267 non-null   object
# ...

# %% [markdown]
# ## Agregar columna "Charges.Daily"

# %%
TelecomX_Data_concat['Charges.Daily'] = TelecomX_Data_concat['Charges.Monthly'] / 30.0

# %% [markdown]
# ## Renombrar/Traducir Columnas

# %%
TelecomX_Data_concat = TelecomX_Data_concat.rename(columns={
    'Churn': 'Cliente_Detractor',
    'gender': 'Genero',
    'SeniorCitizen': 'Usuario_Tercera_Edad',
    'Partner': 'Tiene_Pareja',
    'Dependents': 'Tiene_Dependientes',
    'tenure': 'Meses_Contrato',
    'PhoneService': 'Tiene_Servicio_Telefonico',
    'MultipleLines': 'Tiene_Lineas_multiples',
    'InternetService': 'Servicio_Internet',
    'OnlineBackup': 'Tiene_Backup_Online',
    'OnlineSecurity': 'Tiene_Seguridad_Online',
    'DeviceProtection': 'Tiene_Proteccion_Dispositivos',
    'TechSupport': 'Tiene_Soporte_Tecnico',
    'StreamingTV': 'Tiene_Streaming_TV',
    'StreamingMovies': 'Tiene_Streaming_De_Peliculas',
    'Contract': 'Duración_Contrato',
    'PaperlessBilling': 'Facturacion_Electronica',
    'PaymentMethod': 'Metodo_Pago',
    'Charges.Daily': 'Cargos_Diarios',
    'Charges.Monthly': 'Cargos_Mensuales',
    'Charges.Total': 'Total_Facturado',

})

TelecomX_Data_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customerID                     7267 non-null   object
#  1   Cliente_Detractor              7267 non-null   bool
#  2   Genero                         7267 non-null   object
#  3   Usuario_Tercera_Edad           7267 non-null   bool
#  4   Tiene_Pareja                   7267 non-null   bool
#  5   Tiene_Dependientes             7267 non-null   bool
#  6   Meses_Contrato                 7267 non-null   int64
#  7   Tiene_Servicio_Telefonico      7267 non-null   bool
#  8   Tiene_Lineas_multiples         7267 non-null   bool
#  9   Servicio_Internet              7267 non-null   object
#  10  Tiene_Seguridad_Online         7267 non-null   bool
#  11  Tiene_Backup_Online            7267 non-null   bool
# ...

# %% [markdown]
# ## Corregir valores NaN en columna "Total_Facturado"

# %%
# Filtrar filas con letras
mascara_con_letras = TelecomX_Data_concat['Total_Facturado'].astype(str).str.contains(r'[a-zA-Z]', regex=True)
# Corregir NaN con el valor númerico
valor_corregido = TelecomX_Data_concat['Meses_Contrato'] * TelecomX_Data_concat['Cargos_Mensuales']

TelecomX_Data_concat.loc[mascara_con_letras, 'Total_Facturado'] = valor_corregido[mascara_con_letras]
TelecomX_Data_concat['Total_Facturado'] = TelecomX_Data_concat['Total_Facturado'].astype(float)

# %% [markdown]
# ## Agrupar datos

# %%
# Filtrar solo los clientes detractores
detractores = TelecomX_Data_concat[TelecomX_Data_concat['Cliente_Detractor'] == True]

# Crear columna de perfil combinando Pareja y Dependientes
detractores['Perfil'] = detractores.apply(
    lambda row: f"{'Con Pareja' if row['Tiene_Pareja'] else 'Sin Pareja'} - " +
                f"{'Con Dependientes' if row['Tiene_Dependientes'] else 'Sin Dependientes'}", axis=1)

# Función auxiliar para agrupar y contar
def contar(df):
    return df.groupby('Perfil').size().reindex([
        'Con Pareja - Con Dependientes',
        'Con Pareja - Sin Dependientes',
        'Sin Pareja - Con Dependientes',
        'Sin Pareja - Sin Dependientes'
    ], fill_value=0).reset_index(name='Cantidad')

# Crear Subconjuntos
masc_tercera = contar(detractores[(detractores['Genero'] == 'Male') & (detractores['Usuario_Tercera_Edad'])])
masc_no_tercera = contar(detractores[(detractores['Genero'] == 'Male') & (~detractores['Usuario_Tercera_Edad'])])
fem_tercera = contar(detractores[(detractores['Genero'] == 'Female') & (detractores['Usuario_Tercera_Edad'])])
fem_no_tercera = contar(detractores[(detractores['Genero'] == 'Female') & (~detractores['Usuario_Tercera_Edad'])])
# Out:
# <ipython-input-162-476581469>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ## Gráfico interactivo para comparar detractores en base a su edad, genero, si tienen pareja o personas a su cargo(dependientes)

# %%
# Crear subplots
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=[
        "Masculino - Tercera Edad",
        "Masculino - No Tercera Edad",
        "Femenino - Tercera Edad",
        "Femenino - No Tercera Edad"
    ]
)

# Agregar trazas
fig.add_trace(go.Bar(x=masc_tercera['Perfil'], y=masc_tercera['Cantidad'], name='Masculino T.Edad'), row=1, col=1)
fig.add_trace(go.Bar(x=masc_no_tercera['Perfil'], y=masc_no_tercera['Cantidad'], name='Masculino No T.Edad'), row=1, col=2)
fig.add_trace(go.Bar(x=fem_tercera['Perfil'], y=fem_tercera['Cantidad'], name='Femenino T.Edad', marker_color='pink'), row=2, col=1)
fig.add_trace(go.Bar(x=fem_no_tercera['Perfil'], y=fem_no_tercera['Cantidad'], name='Femenino No T.Edad', marker_color='lightpink'), row=2, col=2)

# Ajustar layout
fig.update_layout(
    height=900,
    width=1400,
    title_text="Clientes Detractores por Género, Tercera Edad, Pareja y Dependientes",
    yaxis_title="Cantidad de Detractores",
    yaxis2_title="Cantidad de Detractores",
    yaxis3_title="Cantidad de Detractores",
    yaxis4_title="Cantidad de Detractores",
    showlegend=False
)

fig.update_xaxes(tickangle=45)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Gráfico para comparar los detractores basado en los servicios que tienen contratados, además de la mediana de tiempo de contrato con la compañia.

# %%
# Inicializar lista para guardar resultados
condiciones = [
    ("Servicio Telefónico", detractores['Tiene_Servicio_Telefonico']),
    ("Soporte Técnico", detractores['Tiene_Soporte_Tecnico']),
    ("Streaming TV", detractores['Tiene_Streaming_TV']),
    ("Streaming Películas", detractores['Tiene_Streaming_De_Peliculas']),
    ("Contrato > 24.57 meses", detractores['Meses_Contrato'] > 24.571773)
]

# Crear DataFrame con conteos
resumen = []
for nombre, serie in condiciones:
    cumple = serie.sum()
    no_cumple = len(serie) - cumple
    resumen.append((nombre, 'Cumple', cumple))
    resumen.append((nombre, 'No Cumple', no_cumple))

df_resumen = pd.DataFrame(resumen, columns=['Condición', 'Estado', 'Cantidad'])

# Crear gráfico de barras agrupadas
fig = px.bar(
    df_resumen,
    x='Condición',
    y='Cantidad',
    color='Estado',
    barmode='group',
    title='Cumplimiento de Condiciones por Clientes Detractores',
    labels={'Cantidad': 'Cantidad de Detractores'}
)

fig.update_layout(xaxis_tickangle=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Gráfico para comparar clientes sin personas a su cargo basado en los servicios contratados y la mediana de tiempo de contrato.

# %%
# Filtrar: clientes detractores SIN dependientes
detractores_sin_dependientes = TelecomX_Data_concat[
    (TelecomX_Data_concat['Cliente_Detractor'] == True) &
    (TelecomX_Data_concat['Tiene_Dependientes'] == False)
]

# Definir condiciones a evaluar
condiciones = [
    ("Servicio Telefónico", detractores_sin_dependientes['Tiene_Servicio_Telefonico']),
    ("Soporte Técnico", detractores_sin_dependientes['Tiene_Soporte_Tecnico']),
    ("Streaming TV", detractores_sin_dependientes['Tiene_Streaming_TV']),
    ("Streaming Películas", detractores_sin_dependientes['Tiene_Streaming_De_Peliculas']),
    ("Contrato > 24.57 meses", detractores_sin_dependientes['Meses_Contrato'] > 24.571773),
]

# Crear DataFrame resumen
resumen = []
for nombre, serie in condiciones:
    cumple = serie.sum()
    no_cumple = len(serie) - cumple
    resumen.append((nombre, 'Cumple', cumple))
    resumen.append((nombre, 'No Cumple', no_cumple))

df_resumen = pd.DataFrame(resumen, columns=['Condición', 'Estado', 'Cantidad'])

# Gráfico de barras agrupadas
fig = px.bar(
    df_resumen,
    x='Condición',
    y='Cantidad',
    color='Estado',
    barmode='group',
    title='Condiciones de Clientes Detractores Sin Dependientes',
    labels={'Cantidad': 'Cantidad de Detractores'}
)

fig.update_layout(xaxis_tickangle=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Gráfico comparativo en cantidad de detractores por el tipo de servicio de internet.

# %%
# Filtrar por los 3 tipos específicos de servicio de internet
tipos_internet = TelecomX_Data_concat['Servicio_Internet'].unique()
detractores_filtrados = detractores[detractores['Servicio_Internet'].isin(tipos_internet)]

# Contar por tipo de servicio de internet
conteo_internet = detractores_filtrados['Servicio_Internet'].value_counts().reset_index()
conteo_internet.columns = ['Servicio_Internet', 'Cantidad']

# Gráfico de barras
fig = px.bar(
    conteo_internet,
    x='Servicio_Internet',
    y='Cantidad',
    title='Cantidad de Clientes Detractores según Tipo de Servicio de Internet',
    labels={'Cantidad': 'Cantidad de Detractores'},
    color='Servicio_Internet',
    color_discrete_map={
        'Fiber optic': 'royalblue',
        'DSL': 'orange',
        'No': 'crimson'
    }
)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Gráfico comparativo en cantidad de detractores basados en el tipo de contrato.

# %%
# Filtrar por los 3 tipos de duración de contrato
tipos_contrato = TelecomX_Data_concat['Duración_Contrato'].unique()
detractores_contrato = detractores[detractores['Duración_Contrato'].isin(tipos_contrato)]

# Contar cuántos hay por tipo de contrato
conteo_contrato = detractores_contrato['Duración_Contrato'].value_counts().reset_index()
conteo_contrato.columns = ['Duración_Contrato', 'Cantidad']

# Gráfico de barras
fig = px.bar(
    conteo_contrato,
    x='Duración_Contrato',
    y='Cantidad',
    title='Cantidad de Clientes Detractores según la Duración del Contrato',
    labels={'Cantidad': 'Cantidad de Detractores'},
    color='Duración_Contrato',
    color_discrete_map={
        'Month-to-month': 'tomato',
        'One year': 'gold',
        'Two year': 'forestgreen'
    }
)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Gráfico para comparar Clientes Detractores por Tipo de Servicio de Internet y Método de Pago

# %%
# Filtrar por tipos válidos
pagos_validos = ['Electronic check', 'Mailed check', 'Bank transfer (automatic)', 'Credit card (automatic)']

detractores_filtrados = detractores[
    (detractores['Servicio_Internet'].isin(tipos_internet)) &
    (detractores['Metodo_Pago'].isin(pagos_validos))
]

# Agrupar y contar por Servicio de Internet y Método de Pago
conteo = detractores_filtrados.groupby(['Servicio_Internet', 'Metodo_Pago']).size().reset_index(name='Cantidad')

# Gráfico de barras agrupadas
fig = px.bar(
    conteo,
    x='Metodo_Pago',
    y='Cantidad',
    color='Servicio_Internet',
    barmode='group',
    title='Clientes Detractores por Tipo de Servicio de Internet y Método de Pago',
    labels={'Cantidad': 'Cantidad de Detractores'},
    color_discrete_map={
        'Fiber optic': 'royalblue',
        'DSL': 'orange',
        'No': 'crimson'
    }
)

# Rotar etiquetas del eje X para mejor lectura
fig.update_layout(xaxis_tickangle=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Gráfico para comparar Clientes Detractores por Método de Pago y Duración del Contrato

# %%
detractores_filtrados = detractores[
    (detractores['Metodo_Pago'].isin(pagos_validos)) &
    (detractores['Duración_Contrato'].isin(tipos_contrato))
]

# Agrupar por Método de Pago y Duración de Contrato
conteo = detractores_filtrados.groupby(['Metodo_Pago', 'Duración_Contrato']).size().reset_index(name='Cantidad')

# Crear gráfico de barras agrupadas
fig = px.bar(
    conteo,
    x='Metodo_Pago',
    y='Cantidad',
    color='Duración_Contrato',
    barmode='group',
    title='Clientes Detractores por Método de Pago y Duración del Contrato',
    labels={'Metodo_Pago': 'Método de Pago', 'Cantidad': 'Cantidad de Detractores'},
    color_discrete_map={
        'Month-to-month': 'tomato',
        'One year': 'gold',
        'Two year': 'forestgreen'
    }
)

fig.update_layout(xaxis_tickangle=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Analisis de valores cuantificables o númericos

# %%
TelecomX_Data_concat[TelecomX_Data_concat['Cliente_Detractor'] == True].describe(include=[float,int] )
# Out:
#        Meses_Contrato  Cargos_Mensuales  Total_Facturado  Cargos_Diarios
# count     1869.000000       1869.000000      1869.000000     1869.000000
# mean        17.979133         74.441332      1531.796094        2.481378
# std         19.531123         24.666053      1890.822994        0.822202
# min          1.000000         18.850000        18.850000        0.628333
# 25%          2.000000         56.150000       134.500000        1.871667
# 50%         10.000000         79.650000       703.550000        2.655000
# 75%         29.000000         94.200000      2331.300000        3.140000
# max         72.000000        118.350000      8684.800000        3.945000
